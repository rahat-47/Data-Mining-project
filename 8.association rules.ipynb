# %% [markdown]
# # **CSI 382 - Data Mining and Knowledge Discovery**

# %% [markdown]
# # **Lab 10 - Association Rules**

# %% [markdown]
# # **Installing packages and importing libraries**

# %%
# !pip install squarify
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
# for basic operations
import numpy as np
import pandas as pd

# for visualizations
import matplotlib.pyplot as plt
import squarify
import seaborn as sns
plt.style.use('fivethirtyeight')

# for defining path
import os

# for market basket analysis
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/colab datasets/06. remaining_behavior_ext.csv')

#Check number of rows and columns in the dataset
print("The dataset has %d rows and %d columns." % df.shape)
# Out:
# The dataset has 34562 rows and 12 columns.
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#lebelencoder
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

#Converting categorical variable to numerical labels
le = LabelEncoder()
df['ip_type'] = le.fit_transform(df['ip_type'])
df['behavior'] = le.fit_transform(df['behavior'])
df['behavior_type'] = le.fit_transform(df['behavior_type'])
df['source'] = le.fit_transform(df['source'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    inter_api_access_duration(sec)  api_access_uniqueness  \
# 0                        7.010387               0.419355
# 1                       51.419393               0.252336
# 2                       25.860775               0.275000
# 3                        0.205909               0.818182
# 4                        0.122125               0.812500
#
#    sequence_length(count)  vsession_duration(min)  ip_type  behavior  \
# 0                    31.0                   13040        1        74
# 1                   107.0                  330113        1        74
# ...

# %%
from typing import BinaryIO
# Assuming you have identified the continuous columns in your dataset
# For example, let's consider 'continuous_columns' as a list of continuous column names

# List of continuous attribute column names (Replace this with your actual continuous column names)
continuous_columns = ['inter_api_access_duration(sec)', 'api_access_uniqueness', 'sequence_length(count)','vsession_duration(min)','ip_type','behavior','behavior_type','num_sessions','num_users','num_unique_apis','source']  # Add your continuous column names here

# Define a threshold for binarization
threshold = 10.0  # Set your threshold value as needed

# Binarize the continuous columns
for column in continuous_columns:
    df[column + '_Binary'] = (df[column] > threshold).astype(int)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    inter_api_access_duration(sec)  api_access_uniqueness  \
# 0                        7.010387               0.419355
# 1                       51.419393               0.252336
# 2                       25.860775               0.275000
# 3                        0.205909               0.818182
# 4                        0.122125               0.812500
#
#    sequence_length(count)  vsession_duration(min)  ip_type  behavior  \
# 0                    31.0                   13040        1        74
# 1                   107.0                  330113        1        74
# ...

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(df.columns[0],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    inter_api_access_duration(sec)_Binary  api_access_uniqueness_Binary  \
# 0                                      0                             0
# 1                                      1                             0
# 2                                      1                             0
# 3                                      0                             0
# 4                                      0                             0
#
#    sequence_length(count)_Binary  vsession_duration(min)_Binary  \
# 0                              1                              1
# ...

# %%
import pandas as pd

# Create an example data (can be empty as there's no header)
data = ["inter_api_access_duration(sec)_Binary","api_access_uniqueness_Binary","sequence_length(count)","sequence_length(count)_Binary","vsession_duration(min)_Binary	","ip_type_Binary","behavior_Binary","behavior_type_Binary","num_sessions_Binary","num_users_Binary","num_unique_apis_Binary","source_Binary"]
# Create a DataFrame without headers
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   File "<ipython-input-48-56a706837ee0>", line 4
#     data = "inter_api_access_duration(sec)_Binary","api_access_uniqueness_Binary","sequence_length(count)","sequence_length(count)_Binary","vsession_duration(min)_Binary	","ip_type_Binary","behavior_Binary","behavior_type_Binary","num_sessions_Binary","num_users_Binary","num_unique_apis_Binary","source_Binary"]
# ...

# %%
df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    inter_api_access_duration(sec)_Binary  api_access_uniqueness_Binary  \
# 0                                      0                             0
# 1                                      1                             0
# 2                                      1                             0
# 3                                      0                             0
# 4                                      0                             0
# 5                                      0                             0
# 6                                      1                             0
# ...

# %%
import pandas as pd

# Example DataFrame with a binary attribute 'Binary_Column'
data = ["inter_api_access_duration(sec)_Binary","api_access_uniqueness_Binary","sequence_length(count)","sequence_length(count)_Binary","vsession_duration(min)_Binary	","ip_type_Binary","behavior_Binary","behavior_type_Binary","num_sessions_Binary","num_users_Binary","num_unique_apis_Binary","source_Binary"]

df = pd.DataFrame(data)

# Convert binary attribute to separate columns using one-hot encoding
one_hot_encoded = pd.get_dummies(df['Binary_Column'], prefix='Binary_Column')

# Concatenate the one-hot encoded columns with the original DataFrame
df = pd.concat([df, one_hot_encoded], axis=1)

# Drop the original 'Binary_Column' if needed
df.drop(columns='Binary_Column', inplace=True)

print(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-f73926fef3fd> in <cell line: 9>()
#       7
#       8 # Convert binary attribute to separate columns using one-hot encoding
# ----> 9 one_hot_encoded = pd.get_dummies(df['Binary_Column'], prefix='Binary_Column')
#      10
#      11 # Concatenate the one-hot encoded columns with the original DataFrame
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
# ...
